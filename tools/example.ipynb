# %% [markdown]
# # Example: Use EventDisplay Class

# %%
# define enviromental variables
# %env SOURCE_DIR=../src
# %env YAML_DIR=../yaml
# Out:
# env: SOURCE_DIR=../src
# env: YAML_DIR=../yaml

# %%
# enable interactive plotting
# %matplotlib widget

# %%
# import EventDisplay class
from event_display import EventDisplay


# expand notebook to full width (this is optional)
from IPython.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
# load a raw data file in root
dp = EventDisplay('../data/test_light_leak_ON_BT_P1_random_220525T1115.root')

# %%
# you can choose width and height of plot being plotted
dp.fig_height=4
dp.fig_width=12
dp.display_waveform(29, 'sum', True)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# plot PMT spatial patterns (still in progress)
dp.get_pmt_hit_pattern(event_id=29, start=2900, end=2950)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
